# %%
# !pip install flask pyngrok
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.12/dist-packages (3.1.3)
# Collecting pyngrok
#   Downloading pyngrok-8.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask) (8.3.3)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask) (3.1.8)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-8.1.2-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-8.1.2

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3E7FqrOnF1PWvjgKRfFxuZ8piPj_5DEBnTkHN8j5g8NWr27oX")

# %%
from flask import Flask
from pyngrok import ngrok

app = Flask(__name__)

@app.route('/')
def home():
    return "Bus Pass System Running"

# create fresh tunnel
public_url = ngrok.connect(5000)
print("PUBLIC URL:", public_url)

app.run(host='0.0.0.0', port=5000)
# Out:
# PUBLIC URL: NgrokTunnel: "https://flight-panther-plant.ngrok-free.dev" -> "http://localhost:5000"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [23/May/2026 08:39:42] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2026 08:42:46] "GET /tickets HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2026 08:43:06] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2026 08:43:27] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [23/May/2026 08:43:35] "GET /tickets HTTP/1.1" 404 -
